# %%
from hanoi import tower_hanoi_n_mooves
from hanoi import print_optimal_moves

# %%
tower_hanoi_n_mooves(2, "A", "B", "C")
# Out:
# 3

# %%
print_optimal_moves(4, "A", "B", "C")
# Out:
# Moving disk from A to B
# Moving disk from A to C
# Moving disk from B to C
# Moving disk from A to B
# Moving disk from C to A
# Moving disk from C to B
# Moving disk from A to B
# Moving disk from A to C
# Moving disk from B to C
# Moving disk from B to A
# Moving disk from C to A
# Moving disk from B to C
# Moving disk from A to B
# Moving disk from A to C
# Moving disk from B to C

# %%
from hanoi import plt_hanoi

# %%
n_disks_list=[i for i in range(1, 10)]
n_moves = [tower_hanoi_n_mooves(i, "A", "B", "C") for i in n_disks_list]

# %%
plt_hanoi(n_disks_list, n_moves)

# %%
# Recursive Python function to solve tower of hanoi


def TowerOfHanoi(n, from_rod, to_rod, aux_rod):
    if n == 0:
        return 
    TowerOfHanoi(n-1, from_rod, aux_rod, to_rod)
    print("Move disk", n, "from rod", from_rod, "to rod", to_rod)
    TowerOfHanoi(n-1, aux_rod, to_rod, from_rod)


# Driver code
N = 1

# A, C, B are the name of rods
TowerOfHanoi(N, 'A', 'C', 'B')

# Contributed By Harshit Agrawal
# Out:
# Move disk 1 from rod A to rod C
